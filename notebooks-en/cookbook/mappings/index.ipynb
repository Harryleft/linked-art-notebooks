# %% [markdown]
# # "Linked Art Cook Book: Mappings"
#
# ---

# %%
# 环境设置
from cromulent import model, vocab

# 设置 base_url 以获得更清晰的输出
model.factory.base_url = 'http://test.com/museum/'

# %% [markdown]
# ## Introduction
#
# This section of the cookbook has mappings between Linked Art and other specifications.
#
# ## Mappings
#
# * [CDWA](cdwa/)
# * [Schema](schema/)
