# %% [markdown]
# # "HAL Link: activityUsedWork"
#
# ---

# %%
# 环境设置
from cromulent import model, vocab

# 设置 base_url 以获得更清晰的输出
model.factory.base_url = 'http://test.com/museum/'

# %% [markdown]
# ## activityUsedWork
#
# Return the activities that used the work.
#
# See the related [model documentation]()
#
# ### Example
#
#
#
#
# ### Details
#
# * Class Given: Work
# * Returns Class: Activity
# * Relationship: used
#
#
# ### SPARQL
