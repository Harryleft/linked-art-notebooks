# %% [markdown]
# # "HAL 链接: 活动UsedWork"
#
# ---

# %%
# 环境设置
from cromulent import model, vocab

# 设置 base_url 以获得更清晰的输出
model.factory.base_url = 'http://test.com/museum/'

# %% [markdown]
# ## 活动UsedWork
#
# 返回 活动 使用 the 作品.
#
# 参见相关的 [模型文档]()
#
# ### 示例
#
#
#
#
# ### 详情
#
# * 给定类: Work
# * 返回类: Activity
# * 关系: 使用
#
#
# ### SPARQL
