# %% [markdown]
# # "HAL 链接: personDeathCa使用ByActivity"
#
# ---

# %%
# 环境设置
from cromulent import model, vocab

# 设置 base_url 以获得更清晰的输出
model.factory.base_url = 'http://test.com/museum/'

# %% [markdown]
# ## personDeathCa使用ByActivity
#
# 返回 people whose death was 由...引起 the 事件 or 活动.
#
# 参见相关的 [模型文档]()
#
# ### 示例
#
# 从...的记录中 the Bubonic Plague, 的记录 a person who died of the plague 将在响应中
#
#
# ### 详情
#
# * 给定类: Event,Activity
# * 返回类: Person
# * 关系:
#
#
# ### SPARQL
