# %% [markdown]
# # Linked Art 中文文档 - Jupyter Notebook 导航
#
# 本目录包含 Linked Art 中文文档的交互式 Jupyter Notebook 版本，所有代码示例都可以直接运行和修改。
#
# ## 使用说明
#
# 1. **运行代码单元格**：点击单元格左侧的 ▶ 按钮，或按 `Shift + Enter`
# 2. **修改代码**：所有代码都可以自由修改和实验
# 3. **查看输出**：每个 crom 代码块会自动显示生成的 JSON-LD 数据
#
# ## 环境要求
#
# ```bash
# pip install cromulent
# ```

# %% [markdown]
# ---
#
# ## 📚 模型文档
#
# ### 核心概念
# - [数据模型概述](model/index.ipynb)
# - [基础模式](model/base/index.ipynb) - 所有实体的核心属性
# - [模型阅读指南](model/intro/index.ipynb)
#
# ### 对象与作品
# - [对象概述](model/object/index.ipynb)
# - [创作与毁坏](model/object/production.ipynb)
# - [物理特征](model/object/physical.ipynb)
# - [相关性](model/object/aboutness.ipynb)
# - [所有权](model/object/ownership.ipynb)
# - [权利信息](model/object/rights.ipynb)
#
# ### 行动者
# - [个人与组织](model/actor/index.ipynb)
#
# ### 流传历史
# - [对象流传历史](model/provenance/index.ipynb)
# - [获得与支付](model/provenance/acquisition.ipynb)
# - [拍卖](model/provenance/auctions.ipynb)
# - [保管权转移](model/provenance/custody.ipynb)
# - [对象发现](model/provenance/encounters.ipynb)
# - [对象移动](model/provenance/movement.ipynb)
# - [承诺与出价](model/provenance/promises.ipynb)
# - [权利转移](model/provenance/rights.ipynb)
# - [未知类型转移](model/provenance/transfer.ipynb)
#
# ### 集藏与展览
# - [集藏](model/collection/index.ipynb)
# - [展览](model/exhibition/index.ipynb)
#
# ### 其他实体
# - [地点](model/place/index.ipynb)
# - [概念](model/concept/index.ipynb)
# - [事件](model/event/index.ipynb)
# - [数字对象](model/digital/index.ipynb)
# - [文档](model/document/index.ipynb)
# - [保护处理](model/conservation/index.ipynb)
#
# ### 词汇表
# - [词汇表概述](model/vocab/index.ipynb)
# - [必需术语](model/vocab/required/index.ipynb)
# - [推荐术语](model/vocab/recommended/index.ipynb)
# - [可选术语](model/vocab/optional/index.ipynb)
#
# ### 其他
# - [档案层级结构](model/archives/index.ipynb)
# - [断言](model/assertion/index.ipynb)
# - [类分析](model/profile/class_analysis.ipynb)

# %% [markdown]
# ---
#
# ## 🔌 API 文档
#
# ### API 概览
# - [API 1.0 概述](api/1.0/index.ipynb)
# - [设计原则](api/1.0/principles/index.ipynb)
# - [协议说明](api/1.0/protocol/index.ipynb)
#
# ### 核心端点
# - [端点概述](api/1.0/endpoint/index.ipynb)
# - [个人端点](api/1.0/endpoint/person.ipynb)
# - [群体端点](api/1.0/endpoint/group.ipynb)
# - [物理对象端点](api/1.0/endpoint/physical_object.ipynb)
# - [数字对象端点](api/1.0/endpoint/digital_object.ipynb)
# - [抽象作品端点](api/1.0/endpoint/abstract_work.ipynb)
# - [视觉作品端点](api/1.0/endpoint/visual_work.ipynb)
# - [文本文作品端点](api/1.0/endpoint/textual_work.ipynb)
# - [集藏端点](api/1.0/endpoint/set.ipynb)
# - [活动端点](api/1.0/endpoint/activity.ipynb)
# - [流传活动端点](api/1.0/endpoint/provenance_activity.ipynb)
# - [地点端点](api/1.0/endpoint/place.ipynb)
# - [概念端点](api/1.0/endpoint/concept.ipynb)
# - [事件端点](api/1.0/endpoint/event.ipynb)
#
# ### 共享结构
# - [共享结构概述](api/1.0/shared/index.ipynb)
# - [活动结构](api/1.0/shared/activity.ipynb)
# - [关系分配](api/1.0/shared/assignment.ipynb)
# - [数字对象](api/1.0/shared/digital.ipynb)
# - [尺寸](api/1.0/shared/dimension.ipynb)
# - [标识符](api/1.0/shared/identifier.ipynb)
# - [金额](api/1.0/shared/money.ipynb)
# - [名称](api/1.0/shared/name.ipynb)
# - [引用](api/1.0/shared/reference.ipynb)
# - [权利](api/1.0/shared/right.ipynb)
# - [声明](api/1.0/shared/statement.ipynb)
# - [时间范围](api/1.0/shared/timespan.ipynb)
# - [类型](api/1.0/shared/type.ipynb)
#
# ### 其他 API 功能
# - [搜索 API](api/1.0/search/index.ipynb)
# - [数据发现](api/1.0/discovery/index.ipynb)
# - [HAL 链接](api/1.0/hal/index.ipynb)
# - [JSON-LD 考虑](api/1.0/json-ld/index.ipynb)
# - [JSON-LD 扩展](api/1.0/json-ld/extensions.ipynb)

# %% [markdown]
# ---
#
# ## 📖 学习路径建议
#
# ### 初学者
# 1. 从 [数据模型概述](model/index.ipynb) 开始
# 2. 学习 [基础模式](model/base/index.ipynb)
# 3. 了解 [对象](model/object/index.ipynb) 和 [行动者](model/actor/index.ipynb)
#
# ### 进阶用户
# 1. 深入 [流传历史](model/provenance/index.ipynb)
# 2. 学习 [API 端点](api/1.0/endpoint/index.ipynb)
# 3. 掌握 [共享结构](api/1.0/shared/index.ipynb)
#
# ### 高级用户
# 1. 研究 [词汇表](model/vocab/index.ipynb)
# 2. 探索 [类分析](model/profile/class_analysis.ipynb)
# 3. 理解 [JSON-LD 扩展](api/1.0/json-ld/extensions.ipynb)

# %%
# 验证环境设置
from cromulent import model, vocab
print(f"cromulent 库已安装，版本可用！\n")
print(f"model 模块: {model}")
print(f"vocab 模块: {vocab}")
# Out:
# cromulent 库已安装，版本可用！
#
# model 模块: <module 'cromulent.model' from 'C:\\Users\\afkxw\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\cromulent\\model.py'>
# vocab 模块: <module 'cromulent.vocab' from 'C:\\Users\\afkxw\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\cromulent\\vocab.py'>
